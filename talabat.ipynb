# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from datetime import datetime, timedelta

# %%
# ML Libraries
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingClassifier
from sklearn.model_selection import train_test_split

# %%
# Time Series Libraries
from prophet import Prophet

# %%
# Importing csv files with reading the date columns and parsing them
df1 = pd.read_csv("fct_order.csv", encoding="cp1252", parse_dates=['order_time'], date_format='%d/%m/%Y %H:%M')
df2 = pd.read_csv("dim_vendor.csv", encoding="cp1252")
df3 = pd.read_csv("dim_date.csv", encoding="cp1252", parse_dates=['iso_date'], date_format="%d-%b-%y")

# %%
print(df1.info())
print(df2.info())
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119885 entries, 0 to 119884
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    119885 non-null  int64
#  1   order_time                  119885 non-null  datetime64[ns]
#  2   vendor_id                   119885 non-null  int64
#  3   analytical_customer_id      119885 non-null  object
#  4   is_acquisition              119885 non-null  bool
#  5   is_successful               119885 non-null  bool
#  6   reason                      19716 non-null   object
#  7   sub_reason                  8348 non-null    object
#  8   owner                       19716 non-null   object
#  9   delivery_arrangement        119885 non-null  object
#  10  gmv_amount_lc               119885 non-null  float64
#  11  basket_amount_lc            119885 non-null  float64
#  12  delivery_fee_amount_lc      119885 non-null  float64
#  13  Payment_Method              119885 non-null  object
#  14  actual_delivery_time        83526 non-null   float64
#  15  promised_delivery_time      83526 non-null   float64
#  16  order_delay                 76184 non-null   float64
#  17  dropoff_distance_manhattan  83524 non-null   float64
#  18  platform                    119885 non-null  object
#  19  vertical_class              119885 non-null  object
#  20  vertical                    119885 non-null  object
#  21  is_affordable_freedelivery  119885 non-null  bool
#  22  is_affordable_item          119885 non-null  bool
#  23  is_affordable_gem           119885 non-null  bool
#  24  is_affordable_restaurant    119885 non-null  bool
#  25  is_affordable_voucher       119885 non-null  bool
#  26  is_affordable               119885 non-null  bool
#  27  affordability_amt_total     31731 non-null   float64
#  28  City_Cluster                118742 non-null  object
#  29  City                        119154 non-null  object
#  30  Zone                        119154 non-null  object
# dtypes: bool(8), datetime64[ns](1), float64(8), int64(2), object(12)
# memory usage: 22.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6151 entries, 0 to 6150
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vendor_id       6151 non-null   int64
#  1   name_en         6151 non-null   object
#  2   chain_name_en   6151 non-null   object
#  3   vertical_class  6151 non-null   object
#  4   vertical        6151 non-null   object
#  5   main_cuisine    6151 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 288.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   iso_date        124 non-null    datetime64[ns]
#  1   year            124 non-null    int64
#  2   year_quarter    124 non-null    object
#  3   year_month_str  124 non-null    object
#  4   Talabat Week    124 non-null    object
#  5   Weekday         124 non-null    object
#  6   Month Q         124 non-null    int64
#  7   day_type_tlb    124 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 7.9+ KB
# None

# %%
df1.columns
# Out:
# Index(['order_id', 'order_time', 'vendor_id', 'analytical_customer_id',
#        'is_acquisition', 'is_successful', 'reason', 'sub_reason', 'owner',
#        'delivery_arrangement', 'gmv_amount_lc', 'basket_amount_lc',
#        'delivery_fee_amount_lc', 'Payment_Method', 'actual_delivery_time',
#        'promised_delivery_time', 'order_delay', 'dropoff_distance_manhattan',
#        'platform', 'vertical_class', 'vertical', 'is_affordable_freedelivery',
#        'is_affordable_item', 'is_affordable_gem', 'is_affordable_restaurant',
#        'is_affordable_voucher', 'is_affordable', 'affordability_amt_total',
#        'City_Cluster', 'City', 'Zone'],
#       dtype='object')

# %%
df1.head()
# Out:
#     order_id          order_time  vendor_id    analytical_customer_id  \
# 0  544145594 2021-09-01 10:41:00     609508  6zWSp9yqnEQuq4N6ykRgbbdQ
# 1  544478492 2021-09-01 18:17:00     602440  TtmFFw26sQR26nBE2RykhxQA
# 2  544358032 2021-09-01 15:56:00     709071  7pB4MC2aBPRdajLH2wPvIvAA
# 3  544366924 2021-09-01 16:09:00     607670  AFedsf0e-lSZer_X0eR4VE-g
# 4  544372362 2021-09-01 16:16:00     616421  JDYqF36aULSEaWsz604DuuRw
#
#    is_acquisition  is_successful reason sub_reason owner delivery_arrangement  \
# 0           False           True    NaN        NaN   NaN                  TGO
# 1           False           True    NaN        NaN   NaN                  TGO
# 2           False           True    NaN        NaN   NaN                  TGO
# 3           False           True    NaN        NaN   NaN                  TGO
# 4           False           True    NaN        NaN   NaN                  TGO
#
#    ...  is_affordable_freedelivery  is_affordable_item  is_affordable_gem  \
# 0  ...                       False               False              False
# 1  ...                       False               False              False
# 2  ...                       False               False              False
# 3  ...                       False               False              False
# 4  ...                       False               False              False
#
#   is_affordable_restaurant  is_affordable_voucher  is_affordable  \
# 0                    False                  False          False
# 1                    False                  False          False
# 2                    False                  False          False
# 3                    False                  False          False
# 4                    False                  False          False
#
#    affordability_amt_total  City_Cluster   City               Zone
# 0                      NaN         Cairo  Cairo        Mohandiseen
# 1                      NaN         Cairo  Cairo  Cairo_city_centre
# 2                      NaN         Cairo  Cairo     Tagamoa 5 east
# 3                      NaN         Cairo  Cairo  Cairo_city_centre
# 4                      NaN         Cairo  Cairo              Maadi
#
# [5 rows x 31 columns]

# %%
df2.head()
# Out:
#    vendor_id                                        name_en  \
# 0     738143            Nutella Waffel 2,Faisal - Kom Bakar
# 1     742299  Waffle Maker, Dokki - Mohy El Din Abou El Ezz
# 2     740938                            Koshary Faisal,Giza
# 3     751673      Koshary w Tawajin Moamen, Al Bahr Al Azam
# 4     763259        Koshary Helmeya Hend, Imbabah - Bashtil
#
#               chain_name_en vertical_class vertical main_cuisine
# 0          Nutella Waffel 2           food     food      Waffles
# 1              Waffle Maker           food     food      Waffles
# 2            Koshary Faisal           food     food      Koshary
# 3  Koshary w Tawajin Moamen           food     food      Koshary
# 4      Koshary Halwani Hend           food     food      Koshary

# %%
df3.head()
# Out:
#     iso_date  year year_quarter year_month_str Talabat Week Weekday  Month Q  \
# 0 2022-01-02  2022       2022-1        2022-01    02-Jan-22     Sun        1
# 1 2022-01-01  2022       2022-1        2022-01    26-Dec-21     Sat        1
# 2 2021-12-31  2021       2021-4        2021-12    26-Dec-21     Fri        4
# 3 2021-12-30  2021       2021-4        2021-12    26-Dec-21     Thu        4
# 4 2021-12-29  2021       2021-4        2021-12    26-Dec-21     Wed        4
#
#   day_type_tlb
# 0      Weekday
# 1      Weekend
# 2      Weekend
# 3      Weekday
# 4      Weekday

# %%
# extracting date from order time from the fact table
df1["order_date"] = df1["order_time"].dt.strftime('%d/%m/%Y')
df3["iso_date"] = pd.to_datetime(df3["iso_date"], format="%d%m%Y")

# %%
# Filter successful orders and count daily 
daily_orders = df1[(df1["is_successful"] == True)].groupby("order_date").size().reset_index(name="orders")
daily_orders
# Out:
#      order_date  orders
# 0    01/01/2022     769
# 1    01/09/2021     819
# 2    01/10/2021     837
# 3    01/11/2021     765
# 4    01/12/2021     764
# ..          ...     ...
# 119  30/10/2021     843
# 120  30/11/2021     795
# 121  30/12/2021     780
# 122  31/10/2021     857
# 123  31/12/2021     822
#
# [124 rows x 2 columns]

# %%
# Full-Range Date Index from Sep 2021 to Jan 2022
range = pd.date_range(start="2021-09-01", end="2022-01-02", freq="d")
daily_orders = daily_orders.reindex()

# %%
px.line(data_frame=daily_orders, x="order_date", y="orders")

# %%
# testing this on our dataset
test_daily_orders = df1[(df1["is_successful"] == True)].groupby("order_date").size().reset_index(name="orders")

# %%
# converting columns to datetime
daily_orders["order_date"] = pd.to_datetime(daily_orders["order_date"], format='%d/%m/%Y')
daily_orders = daily_orders.sort_values('order_date')

# %%
# Adding a feature (as documented in the excel that the talabt day starts from sunday and ends on saturday )
daily_orders["talabat_week"] = (daily_orders["order_date"].dt.day_of_week + 1) % 7

# %%
# preprare train and test split
# Use 75% for training (1st of Sep to 2nd of December) and test the rest (from 3rd of December to 2nd of Jan)
train_end = '2021-12-02'
test_start = '2021-12-03'
train_data = daily_orders[daily_orders["order_date"] <= train_end]
test_data = daily_orders[(daily_orders["order_date"] >= test_start) & (daily_orders["order_date"] <= '2021-01-02')]

# %%
# Firstly, we'll test on Nov and Dec
test_cut = '2021-11-01'
train = train_data[train_data["order_date"] < test_cut]
test = train_data[train_data["order_date"] >= test_cut]

# %%
train_data["order_year"] =train_data["order_date"].dt.year 
train_data["order_month"] =train_data["order_date"].dt.month
train_data["order_day"] =train_data["order_date"].dt.day
# Out:
# C:\Users\ezzel\AppData\Local\Temp\ipykernel_20616\4190417397.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ezzel\AppData\Local\Temp\ipykernel_20616\4190417397.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ezzel\AppData\Local\Temp\ipykernel_20616\4190417397.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_data = train_data.drop('order_date', axis=1)
train_data
# Out:
#      orders  talabat_week  order_year  order_month  order_day
# 1       819             3        2021            9          1
# 6       856             4        2021            9          2
# 10      837             5        2021            9          3
# 14      845             6        2021            9          4
# 18      847             0        2021            9          5
# ..      ...           ...         ...          ...        ...
# 112     779             0        2021           11         28
# 116     719             1        2021           11         29
# 120     795             2        2021           11         30
# 4       764             3        2021           12          1
# 9       800             4        2021           12          2
#
# [93 rows x 5 columns]

# %%
xx = train_data[["order_year", "order_month", "order_day", "talabat_week"]]
yy = train_data[["orders"]]

# %%
train_x, test_x, train_y, test_y = train_test_split(xx, yy, test_size=0.25, random_state=1)

# %%
print(f"Train size on {len(train_x)} days, while Test Size on {len(test_x)} day")
# Out:
# Train size on 69 days, while Test Size on 24 day

# %%
test_model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6)

# %%
test_model.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
predictions = test_model.predict(test_x)

# %%
predictions
# Out:
# array([844.24725, 745.9097 , 840.7999 , 861.68964, 719.1534 , 769.0299 ,
#        833.2549 , 808.5979 , 864.68506, 783.55023, 852.82666, 822.27045,
#        819.0204 , 792.3177 , 808.4776 , 864.42676, 839.64374, 860.1632 ,
#        805.68835, 789.1963 , 803.34845, 818.09686, 805.8876 , 811.6881 ],
#       dtype=float32)

# %%
nov_dec_test = pd.DataFrame({
    "actual": test_y.orders,
    "predicted": predictions,
    "dow": test_x['talabat_week'].values
}, index=test_y.index)

# %%
nov_dec_test
# Out:
#      actual   predicted  dow
# 119     843  844.247253    6
# 56      736  745.909729    0
# 59      848  840.799927    5
# 107     841  861.689636    3
# 112     779  719.153381    0
# 68      784  769.029907    3
# 8       780  833.254883    2
# 95      838  808.597900    0
# 99      790  864.685059    1
# 39      786  783.550232    0
# 43      859  852.826660    1
# 7       790  822.270447    6
# 120     795  819.020386    2
# 110     900  792.317688    2
# 35      823  808.477600    6
# 103     880  864.426758    2
# 42      740  839.643738    6
# 10      837  860.163208    5
# 9       800  805.688354    4
# 52      815  789.196289    6
# 75      817  803.348450    2
# 78      812  818.096863    1
# 108     764  805.887573    6
# 27      792  811.688110    4

# %%
# Getting Mean Absolute Error and Mean Absolute Percentage Error
mae = mean_absolute_error(test_y, predictions)
MAPE = mean_absolute_percentage_error(test_y, predictions) * 100
print(f"MAE = {mae:.2f} Orders")
print(f"MAPE = {MAPE}%")
# Out:
# MAE = 29.56 Orders
# MAPE = 3.6800548434257507%

# %%
# Since any model cannot take datetime dtype so we're going to convert it to a numeric feature
test_daily_orders["order_year"] = daily_orders["order_date"].dt.year
test_daily_orders["order_month"] = daily_orders["order_date"].dt.month
test_daily_orders["order_day"] = daily_orders["order_date"].dt.day
test_daily_orders["dayofyear"] = daily_orders["order_date"].dt.dayofyear
test_daily_orders["quarter"] = daily_orders["order_date"].dt.quarter

# %%
test_daily_orders = test_daily_orders.drop('quarter', axis=1)
test_daily_orders
# Out:
#      order_date  orders  order_year  order_month  order_day  dayofyear
# 0    01/01/2022     769        2022            1          1          1
# 1    01/09/2021     819        2021            9          1        244
# 2    01/10/2021     837        2021           10          1        274
# 3    01/11/2021     765        2021           11          1        305
# 4    01/12/2021     764        2021           12          1        335
# ..          ...     ...         ...          ...        ...        ...
# 119  30/10/2021     843        2021           10         30        303
# 120  30/11/2021     795        2021           11         30        334
# 121  30/12/2021     780        2021           12         30        364
# 122  31/10/2021     857        2021           10         31        304
# 123  31/12/2021     822        2021           12         31        365
#
# [124 rows x 6 columns]

# %%
test_daily_orders = test_daily_orders.drop('order_date', axis=1)
test_daily_orders
# Out:
#      orders  order_year  order_month  order_day  dayofyear
# 0       769        2022            1          1          1
# 1       819        2021            9          1        244
# 2       837        2021           10          1        274
# 3       765        2021           11          1        305
# 4       764        2021           12          1        335
# ..      ...         ...          ...        ...        ...
# 119     843        2021           10         30        303
# 120     795        2021           11         30        334
# 121     780        2021           12         30        364
# 122     857        2021           10         31        304
# 123     822        2021           12         31        365
#
# [124 rows x 5 columns]

# %%
# Prepare X, y
X = test_daily_orders[["order_day", "order_month", "order_year"]]
y = test_daily_orders[["orders"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(f"Train size on {len(x_train)} days, while Test Size on {len(x_test)} day")
# Out:
# Train size on 99 days, while Test Size on 25 day

# %%
# Since the model's error is relatively low, we can use it on all the train data and the above was a test on a small set of the df
model = XGBRegressor(n_estimators=20, max_depth=12, learning_rate=0.1, random_state=42, subsample=0.5)

# %%
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=20,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([798.579  , 860.1427 , 786.0391 , 856.3981 , 766.8424 , 817.84143,
#        803.0987 , 851.8929 , 848.8554 , 786.99084, 832.5295 , 771.54297,
#        803.0164 , 780.72626, 860.2114 , 800.19556, 786.2049 , 779.11523,
#        860.1427 , 828.0362 , 789.96844, 834.384  , 745.8381 , 778.0254 ,
#        772.3341 ], dtype=float32)

# %%
y_test.orders.dtype
# Out:
# dtype('int64')

# %%
results = pd.DataFrame({
    "actual": y_test.orders,
    "predicted": prediction
}, index=y_test.index)

# %%
# Calculate Error metrics
mae = mean_absolute_error(results['actual'], results['predicted'])
mape = mean_absolute_percentage_error(y_true=results['actual'], y_pred=results['predicted']) * 100

# %%
print(f"Model Performance:")
print(f"Mean Absolute Error: {mae:.2f} orders")
print(f"Mean Absolute Percentage Error: {mape:.2f}%")
# Out:
# Model Performance:
# Mean Absolute Error: 40.16 orders
# Mean Absolute Percentage Error: 4.89%

# %% [markdown]
# #### Using Prophet Model
#
# - Prophet is a forecasting procedure designed for business time series data developed by Facebook's Core Data Science team.

# %%
from prophet import Prophet

# %%
daily_orders = daily_orders.drop('talabat_week', axis=1)
daily_orders = daily_orders.rename(columns={"order_date": "ds", "orders":"y"})
daily_orders
# Out:
#             ds    y
# 1   2021-09-01  819
# 6   2021-09-02  856
# 10  2021-09-03  837
# 14  2021-09-04  845
# 18  2021-09-05  847
# ..         ...  ...
# 117 2021-12-29  840
# 121 2021-12-30  780
# 123 2021-12-31  822
# 0   2022-01-01  769
# 5   2022-01-02  793
#
# [124 rows x 2 columns]

# %%
p_model = Prophet(weekly_seasonality=True, yearly_seasonality=False)

# %%
p_model.fit(daily_orders)
# Out:
# 16:18:46 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:47 - cmdstanpy - INFO - Chain [1] done processing

# %%
jan_feb = p_model.make_future_dataframe(periods=59, freq="D")
jan_feb = jan_feb[jan_feb['ds'].dt.year.isin([2022])]
jan_feb = jan_feb[jan_feb['ds'].dt.month.isin([1,2])]

# %%
forecast = p_model.predict(jan_feb)

# %%
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'weekly', 'weekly_lower', 'weekly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
results = forecast[['ds', 'yhat_lower', 'yhat_upper', 'yhat']]
results
# Out:
#            ds  yhat_lower  yhat_upper        yhat
# 0  2022-01-01  715.412462  802.291993  761.294935
# 1  2022-01-02  697.672040  791.776216  744.841850
# 2  2022-01-03  697.107613  789.199879  743.426041
# 3  2022-01-04  727.303866  819.934394  774.583903
# 4  2022-01-05  721.387465  813.190353  768.124606
# 5  2022-01-06  744.460565  833.972682  787.889819
# 6  2022-01-07  761.086946  854.738821  807.877152
# 7  2022-01-08  711.853355  805.640790  757.255775
# 8  2022-01-09  692.592228  783.881901  740.802690
# 9  2022-01-10  692.339265  787.159648  739.386881
# 10 2022-01-11  725.619946  812.795137  770.544743
# 11 2022-01-12  716.027855  811.278802  764.085446
# 12 2022-01-13  736.738632  831.468576  783.850659
# 13 2022-01-14  758.471379  849.904314  803.837992
# 14 2022-01-15  708.685143  800.554987  753.216615
# 15 2022-01-16  692.758636  783.615765  736.763530
# 16 2022-01-17  690.846287  781.265694  735.347721
# 17 2022-01-18  721.323088  812.645165  766.505583
# 18 2022-01-19  709.454060  805.759329  760.046286
# 19 2022-01-20  731.628621  824.725017  779.811499
# 20 2022-01-21  756.704408  848.188156  799.798832
# 21 2022-01-22  705.044657  798.253670  749.177455
# 22 2022-01-23  687.848260  778.079282  732.724370
# 23 2022-01-24  684.416612  775.457580  731.308561
# 24 2022-01-25  717.789342  803.757046  762.466423
# 25 2022-01-26  709.224577  802.734849  756.007126
# 26 2022-01-27  727.541909  819.812831  775.772339
# 27 2022-01-28  747.549815  842.996475  795.759672
# 28 2022-01-29  698.276698  791.290043  745.138295
# 29 2022-01-30  683.708682  775.374591  728.685209
# 30 2022-01-31  680.953601  772.618724  727.269401
# 31 2022-02-01  713.355192  802.974806  758.427263
# 32 2022-02-02  704.623153  797.218538  751.967966
# 33 2022-02-03  724.177794  817.260529  771.733179
# 34 2022-02-04  745.596676  833.157942  791.720512
# 35 2022-02-05  699.379440  789.318254  741.099135
# 36 2022-02-06  681.773207  767.439947  724.646049
# 37 2022-02-07  677.807242  769.147502  723.230240
# 38 2022-02-08  708.618103  803.065276  754.388102
# 39 2022-02-09  698.005377  793.484370  747.928806
# 40 2022-02-10  720.043258  813.767749  767.694019
# 41 2022-02-11  745.920213  834.508559  787.681352
# 42 2022-02-12  690.665226  783.686710  737.059975
# 43 2022-02-13  676.614507  765.009352  720.606889
# 44 2022-02-14  674.767339  767.062140  719.191080
# 45 2022-02-15  703.746903  798.625787  750.348942
# 46 2022-02-16  699.366877  791.422209  743.889646
# 47 2022-02-17  718.516231  810.329502  763.654859
# 48 2022-02-18  740.026270  830.694503  783.642192
# 49 2022-02-19  687.737589  778.624848  733.020815
# 50 2022-02-20  670.677519  759.561455  716.567729
# 51 2022-02-21  669.665608  763.196513  715.151920
# 52 2022-02-22  700.688736  796.029379  746.309782
# 53 2022-02-23  691.373993  786.276428  739.850486
# 54 2022-02-24  716.203986  805.026734  759.615699
# 55 2022-02-25  734.149153  825.492946  779.603031
# 56 2022-02-26  685.855136  775.898865  728.981654
# 57 2022-02-27  660.876780  759.193933  712.528569
# 58 2022-02-28  664.946123  755.813512  711.112760

# %%
results.to_csv("forecast_prediction.csv", index=False)
